# %%
#import Dependencies
import pandas as pd
import numpy as np
import requests
from pprint import pprint
from sqlalchemy import create_engine

# %% [markdown]
# ## import firstgen pokemon csv

# %%
csv_file = "Resources/FirstGenPokemon.csv"
firstgen_df = pd.read_csv(csv_file)
firstgen_df
# Out:
#      Number        Name   Types    Type1   Type2   Height(m)   Weight(kg)  \
# 0         1   Bulbasaur       2    grass  poison         0.7          6.9
# 1         2     Ivysaur       2    grass  poison         1.0         13.0
# 2         3    Venusaur       2    grass  poison         2.0        100.0
# 3         4  Charmander       1     fire    None         0.6          8.5
# 4         5  Charmeleon       1     fire    None         1.1         19.0
# ..      ...         ...     ...      ...     ...         ...          ...
# 146     147     Dratini       1   dragon    None         1.8          3.3
# 147     148   Dragonair       1   dragon    None         4.0         16.5
# 148     149   Dragonite       2   dragon  flying         2.2        210.0
# 149     150      Mewtwo       1  psychic    None         2.0        122.0
# 150     151         Mew       1  psychic    None         0.4          4.0
#
#       Male_Pct   Female_Pct   Capt_Rate  ...   Poison_Dmg  Ground_Dmg  \
# ...

# %%
#clean data
#remove spaces from column names
firstgen_df.columns = firstgen_df.columns.str.replace(' ', '')

# %%
firstgen_cleaned= firstgen_df[['Number','Name','Type1','Height(m)','Weight(kg)']].copy()
firstgen_cleaned.set_index("Number", inplace=True)
firstgen_renamed=firstgen_cleaned.rename(columns={"Number": "number","Name": "name","Type1": "type", "Height(m)": "height_m","Weight(kg)":"weight_kg"})
firstgen_renamed.index.names = ['number']
firstgen_renamed
# Out:
#               name     type  height_m  weight_kg
# number
# 1        Bulbasaur    grass       0.7        6.9
# 2          Ivysaur    grass       1.0       13.0
# 3         Venusaur    grass       2.0      100.0
# 4       Charmander     fire       0.6        8.5
# 5       Charmeleon     fire       1.1       19.0
# ...            ...      ...       ...        ...
# 147        Dratini   dragon       1.8        3.3
# 148      Dragonair   dragon       4.0       16.5
# 149      Dragonite   dragon       2.2      210.0
# 150         Mewtwo  psychic       2.0      122.0
# 151            Mew  psychic       0.4        4.0
#
# [151 rows x 4 columns]

# %% [markdown]
# ## gather 2nd gen data from API

# %%
#create list to hold numbers for 2nd gen pokemon
num_list = [i for i in range(152,252)]

# set up lists to hold reponse info
name=[]
type1=[]
height=[]
weight=[]
number=[]

# %%
#partial query URL
query_url = "https://pokeapi.co/api/v2/pokemon/"

# %%
#test out query url
response_1 = requests.get(query_url + '100').json()
pprint(response_1)
# Out:
# {'abilities': [{'ability': {'name': 'aftermath',
#                             'url': 'https://pokeapi.co/api/v2/ability/106/'},
#                 'is_hidden': True,
#                 'slot': 3},
#                {'ability': {'name': 'static',
#                             'url': 'https://pokeapi.co/api/v2/ability/9/'},
#                 'is_hidden': False,
#                 'slot': 2},
#                {'ability': {'name': 'soundproof',
#                             'url': 'https://pokeapi.co/api/v2/ability/43/'},
#                 'is_hidden': False,
#                 'slot': 1}],
#  'base_experience': 66,
#  'forms': [{'name': 'voltorb',
#             'url': 'https://pokeapi.co/api/v2/pokemon-form/100/'}],
#  'game_indices': [{'game_index': 100,
#                    'version': {'name': 'white-2',
#                                'url': 'https://pokeapi.co/api/v2/version/22/'}},
#                   {'game_index': 100,
#                    'version': {'name': 'black-2',
# ...

# %%
#query API using loop and save all values to lists
index_counter=1
for num in num_list:
    response = requests.get(query_url + str(num)).json()
    name.append(response['name'])
    height.append(response['height'])
    weight.append(response['weight'])
    number.append(response['id'])
    type1.append(response['types'][0]['type']['name'])
    print(f"Processing Record {index_counter}")
    index_counter += 1
# Out:
# Processing Record 1
# Processing Record 2
# Processing Record 3
# Processing Record 4
# Processing Record 5
# Processing Record 6
# Processing Record 7
# Processing Record 8
# Processing Record 9
# Processing Record 10
# Processing Record 11
# Processing Record 12
# Processing Record 13
# Processing Record 14
# Processing Record 15
# Processing Record 16
# Processing Record 17
# Processing Record 18
# Processing Record 19
# Processing Record 20
# Processing Record 21
# Processing Record 22
# Processing Record 23
# Processing Record 24
# Processing Record 25
# Processing Record 26
# Processing Record 27
# Processing Record 28
# Processing Record 29
# Processing Record 30
# Processing Record 31
# Processing Record 32
# Processing Record 33
# Processing Record 34
# Processing Record 35
# Processing Record 36
# Processing Record 37
# Processing Record 38
# Processing Record 39
# Processing Record 40
# Processing Record 41
# Processing Record 42
# Processing Record 43
# ...

# %%
# create a data frame from pokemon
secondgen_dict = {
    "number": number,
    "name": name,
    "type": type1,
    "height_m": height,
    "weight_kg": weight
    
}

secondgen_data = pd.DataFrame(secondgen_dict)
secondgen_data =secondgen_data.set_index('number')
secondgen_data.head()
# Out:
#              name   type  height_m  weight_kg
# number
# 152     chikorita  grass         9         64
# 153       bayleef  grass        12        158
# 154      meganium  grass        18       1005
# 155     cyndaquil   fire         5         79
# 156       quilava   fire         9        190

# %% [markdown]
# ## connect to database

# %%
connection_string = "postgres:postgres@localhost:5432/Pokemon"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['firstgen', 'secondgen']

# %% [markdown]
# ## load dataframes into database

# %%
firstgen_renamed.to_sql(name='firstgen', con=engine, if_exists='append', index=True)

# %%
secondgen_data.to_sql(name='secondgen', con=engine, if_exists='append', index=True)
